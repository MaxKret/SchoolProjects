# %%
# import the packages 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('AidData.xlsx')

# %%
df
# Out:
#      aiddata_id  ...                         coalesced_purpose_name
# 0       3002660  ...  Forestry policy and administrative management
# 1       3004433  ...                               Higher education
# 2       8448267  ...                                Multisector aid
# 3       8672056  ...             Employment policy and admin. mgmt.
# 4       8777452  ...                                Multisector aid
# ..          ...  ...                                            ...
# 494    98684800  ...            Informal/semi-formal fin. intermed.
# 495    98687831  ...          Water supply & sanit. - large systems
# 496    98699219  ...                             Emergency food aid
# 497    98721463  ...     Democratic participation and civil society
# 498    98755850  ...           Advanced tech. & managerial training
#
# [499 rows x 7 columns]

# %%
df['coalesced_purpose_code'].min()
df['coalesced_purpose_code'].max()
# Out:
# 99820
